# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
car_data = pd.read_csv(r'D:\python\datasets\Cardetails.csv')

# %%
car_data.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
car_data.drop(columns=['torque'],inplace=True)

# %%
car_data.shape
# Out:
# (8128, 12)

# %%
#preprocessing
#null check
car_data.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# seats            221
# dtype: int64

# %%
car_data.dropna(inplace=True)

# %%
car_data.shape
# Out:
# (7907, 12)

# %%
#duplicate check
car_data.duplicated().sum()
# Out:
# np.int64(1189)

# %%
car_data.drop_duplicates(inplace=True)

# %%
car_data.shape
# Out:
# (6718, 12)

# %%
car_data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 6718 entries, 0 to 8125
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6718 non-null   str
#  1   year           6718 non-null   int64
#  2   selling_price  6718 non-null   int64
#  3   km_driven      6718 non-null   int64
#  4   fuel           6718 non-null   str
#  5   seller_type    6718 non-null   str
#  6   transmission   6718 non-null   str
#  7   owner          6718 non-null   str
#  8   mileage        6718 non-null   str
#  9   engine         6718 non-null   str
#  10  max_power      6718 non-null   str
#  11  seats          6718 non-null   float64
# dtypes: float64(1), int64(3), str(8)
# memory usage: 1.2 MB

# %%
for col in car_data.columns:
    print('unique values of ' + col)
    print(car_data[col].unique())
    print("------------------\n")
# Out:
# unique values of name
# <ArrowStringArray>
# [                      'Maruti Swift Dzire VDI',
#                  'Skoda Rapid 1.5 TDI Ambition',
#                      'Honda City 2017-2020 EXi',
#                     'Hyundai i20 Sportz Diesel',
#                        'Maruti Swift VXI BSIII',
#                 'Hyundai Xcent 1.2 VTVT E Plus',
#                  'Maruti Wagon R LXI DUO BSIII',
#                            'Maruti 800 DX BSII',
#                              'Toyota Etios VXD',
#          'Ford Figo Diesel Celebration Edition',
#  ...
#                     'Toyota Innova 2.5 E 7 STR',
#                             'Honda City ZXi AT',
#                  'Ford Fiesta 1.4 Duratorq EXI',
#                            'Chevrolet Cruze LT',
#                   'Maruti Celerio ZXI AMT BSIV',
#                         'Tata Bolt Revotron XM',
#            'Tata Manza Aura (ABS) Safire BS IV',
#                    'Tata Nexon 1.5 Revotorq XT',
# ...

# %%
def get_brand_name(car_name):
    car_name = car_name.split(' ')[0]
    return car_name.strip(' ')

# %%
def clean_data(name):
    name = name.split(' ')[0]
    name = name.strip()
    if name == '':
        name=0
    return float(name)

# %%
get_brand_name('maruti suzuki swift dzire vdi')
# Out:
# 'maruti'

# %%
car_data['name'] = car_data['name'].apply(get_brand_name)

# %%
car_data['name'].unique()
# Out:
# <ArrowStringArray>
# [       'Maruti',         'Skoda',         'Honda',       'Hyundai',
#         'Toyota',          'Ford',       'Renault',      'Mahindra',
#           'Tata',     'Chevrolet',        'Datsun',          'Jeep',
#  'Mercedes-Benz',    'Mitsubishi',          'Audi',    'Volkswagen',
#            'BMW',        'Nissan',         'Lexus',        'Jaguar',
#           'Land',            'MG',         'Volvo',        'Daewoo',
#            'Kia',          'Fiat',         'Force',    'Ambassador',
#          'Ashok',         'Isuzu',          'Opel']
# Length: 31, dtype: str

# %%
brand_mapping = {
    'Maruti': 1,
    'Skoda': 2,
    'Honda': 3,
    'Hyundai': 4,
    'Toyota': 5,
    'Ford': 6,
    'Renault': 7,
    'Mahindra': 8,
    'Tata': 9,
    'Chevrolet': 10,
    'Datsun': 11,
    'Jeep': 12,
    'Mercedes-Benz': 13,
    'Mitsubishi': 14,
    'Audi': 15,
    'Volkswagen': 16,
    'BMW': 17,
    'Nissan': 18,
    'Lexus': 19,
    'Jaguar': 20,
    'Land': 21,
    'MG': 22,
    'Volvo': 23,
    'Daewoo': 24,
    'Kia': 25,
    'Fiat': 26,
    'Force': 27,
    'Ambassador': 28,
    'Ashok': 29,
    'Isuzu': 30,
    'Opel': 31
}

car_data['name'] = car_data['name'].replace(brand_mapping)

# %%
car_data['transmission'].unique()
# Out:
# <ArrowStringArray>
# ['Manual', 'Automatic']
# Length: 2, dtype: str

# %%
car_data['transmission'] = car_data['transmission'].map({
    'Manual': 1,
    'Automatic': 2
})

# %%
car_data['seller_type'].unique()
# Out:
# <ArrowStringArray>
# ['Individual', 'Dealer', 'Trustmark Dealer']
# Length: 3, dtype: str

# %%
car_data['seller_type'] = car_data['seller_type'].map({
    'Individual': 1,
    'Dealer': 2,
    'Trustmark Dealer': 3
})

# %%
car_data['fuel'].unique()
# Out:
# <ArrowStringArray>
# ['Diesel', 'Petrol', 'LPG', 'CNG']
# Length: 4, dtype: str

# %%
car_data['fuel'] = car_data['fuel'].map({
    'Diesel': 1,
    'Petrol': 2,
    'LPG': 3,
    'CNG': 4
})

# %%
car_data.reset_index(inplace=True)

# %%
car_data['owner'].unique()
# Out:
# <ArrowStringArray>
# [         'First Owner',         'Second Owner',          'Third Owner',
#  'Fourth & Above Owner',       'Test Drive Car']
# Length: 5, dtype: str

# %%
car_data['owner'] = car_data['owner'].map({
    'First Owner': 1,
    'Second Owner': 2,
    'Third Owner': 3,
    'Fourth & Above Owner': 4,
    'Test Drive Car': 5
})

# %%
car_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6718 entries, 0 to 6717
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          6718 non-null   int64
#  1   name           6718 non-null   object
#  2   year           6718 non-null   int64
#  3   selling_price  6718 non-null   int64
#  4   km_driven      6718 non-null   int64
#  5   fuel           6718 non-null   int64
#  6   seller_type    6718 non-null   int64
#  7   transmission   6718 non-null   int64
#  8   owner          6718 non-null   int64
#  9   mileage        6718 non-null   str
#  10  engine         6718 non-null   str
#  11  max_power      6718 non-null   str
#  12  seats          6718 non-null   float64
# dtypes: float64(1), int64(8), object(1), str(3)
# memory usage: 842.2+ KB

# %%
car_data['mileage'] = car_data['mileage'].apply(clean_data)

# %%
car_data['max_power'] = car_data['max_power'].apply(clean_data)

# %%
car_data['engine'] = car_data['engine'].apply(clean_data)

# %%
car_data
# Out:
#       index name  year  selling_price  km_driven  fuel  seller_type  \
# 0         0    1  2014         450000     145500     1            1
# 1         1    2  2014         370000     120000     1            1
# 2         2    3  2006         158000     140000     2            1
# 3         3    4  2010         225000     127000     1            1
# 4         4    1  2007         130000     120000     2            1
# ...     ...  ...   ...            ...        ...   ...          ...
# 6713   8121    1  2013         260000      50000     2            1
# 6714   8122    4  2014         475000      80000     1            1
# 6715   8123    4  2013         320000     110000     2            1
# 6716   8124    4  2007         135000     119000     1            1
# 6717   8125    1  2009         382000     120000     1            1
#
#       transmission  owner  mileage  engine  max_power  seats
# 0                1      1    23.40  1248.0      74.00    5.0
# ...

# %%
car_data.drop(columns=['index'],inplace=True)

# %%
#model training:
input_data = car_data.drop(columns=['selling_price'])
output_data = car_data['selling_price']

# %%
x_train,x_test,y_train,y_test=train_test_split(input_data,output_data,test_size=0.2)

# %%
#Model Creation:
model = LinearRegression()

# %%
#Training model:
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predict = model.predict(x_test)

# %%
print(predict)
# Out:
# [ 310269.54384109 1068535.38447808  350616.83403946 ...  538647.45659119
#   471581.63738632  601264.65951762]

# %%
x_train.shape
# Out:
# (5374, 11)

# %%
x_train.head(1)
# Out:
#      name  year  km_driven  fuel  seller_type  transmission  owner  mileage  \
# 1129    4  2014     146000     1            1             2      2    13.01
#
#       engine  max_power  seats
# 1129  2199.0      194.3    7.0

# %%
input_data_model = pd.DataFrame(x_train.head(1))

# %%
model.predict(input_data_model)
# Out:
# array([1706186.1716122])

# %%
import pickle as pk

# %%
pk.dump(model,open('model.pkl','wb'))
